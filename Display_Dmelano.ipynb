# %%
library(readr)
library(tidyr)
library(dplyr)
library(stringr)
library(ggplot2)

# %%
dmelanog_fps = dir("results", full.names=TRUE)
erase = function(patt, x) {gsub(patt, "", x)}

dmelano_dfs = setNames(lapply(dmelanog_fps, function(x){
    read_tsv(x, col_types = cols(.default = "c"))
}), erase("results/|\\.tsv", dmelanog_fps))
names(dmelano_dfs)
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details, e.g.:
#   dat <- vroom(...)
#   problems(dat)”
#  [1] "anno_active_site_uptable"          "anno_alternative_sequence_uptable"
#  [3] "anno_beta_strand_uptable"          "anno_binding_site_uptable"
#  [5] "anno_chain_uptable"                "anno_coiled_coil_uptable"
#  [7] "anno_compositional_bias_uptable"   "anno_cross_link_uptable"
#  [9] "anno_disulfide_bond_uptable"       "anno_dna_binding_uptable"
# [11] "anno_domain_ft_uptable"            "anno_glycosylation_uptable"
# [13] "anno_helix_uptable"                "anno_initiator_methionine_uptable"
# [15] "anno_intramembrane_uptable"        "anno_lipidation_uptable"
# [17] "anno_modified_residue_uptable"     "anno_motif_uptable"
# [19] "anno_mutagenesis_uptable"          "anno_natural_variant_uptable"
# [21] "anno_non_standard_residue_uptable" "anno_peptide_uptable"
# [23] "anno_propeptide_uptable"           "anno_region_uptable"
# ...

# %%
lapply(dmelano_dfs, function(x) {head(x)})
# Out:
# ERROR while rich displaying an object: Error in make.names(x): invalid multibyte string at '<80><95>'
#
# Traceback:
# 1. sapply(x, f, simplify = simplify)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. doTryCatch(return(expr), name, parentenv, handler)
# 8. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
# ...
